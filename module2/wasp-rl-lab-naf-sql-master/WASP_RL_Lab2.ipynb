# %% [markdown]
# # WASP RL - Meeting 2 - Lab assignment on NAF  and SQL
#
# In this lab we implement and experiment with NAF and SQL, both algorithms we learned about in the course and both can deal with continuous state **and** action spaces. Both algorithms employ deep neural networks for function approximation. To do this assignment, you will need to work with PyTorch, a popular framework for developing neural networks. When forming groups, make sure that at least one group member if comfortable with PyTorch and its most common tensor operations.
#
# This notebook has been created specifically for this course and this session by *Finn Rietz* and *Johannes A. Stork*, we hope you enjoy the lab :)

# %%
# install requirements if needed
import sys
# !{sys.executable} -m pip install gym[classic_control]==0.26.2 numpy==1.23.0 matplotlib==3.1.2 
# !{sys.executable} -m pip install torch==1.12.0 torchaudio==0.12.0 torchvision==0.13.0 scipy==1.3.3

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kde
import random
# %matplotlib inline
plt.rcParams['figure.dpi'] = 100

import torch
import torch.nn as nn
from torch.distributions import MultivariateNormal
from torch.optim import Adam

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device("cpu")
print(f"torch device: {DEVICE}")

from buffer import ReplayBuffer
from utils import presample_env, transform_action, smooth, obs_transform, OUNoise, rbf_kernel2
from env_v2 import MultiGoalEnv
from network import MLP
from plotting import plot_loss, plot_reward
# Out:
# torch device: cpu

# %%
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

# %% [markdown]
# # NAF
# We start with NAF. From the paper, we know that the value $V(\mathbf{x} | \theta)$, the action $\mathbf{\mu(x|}\theta)$, and the matrix entries $\mathbf{L(x}|\theta)$ are being approximated by neural networks. Its easiest to just have one a single neural network with multiple output heads for each quantity. As a first step, **adjust the code below so that the network outputs the desired values**. This involves making output layers for each quantity and implementing the equations for $Q(x,u)|\theta)$ and $A(x, u |\theta)$ in the forward pass of the neural network:
# ![NAF quantities](notebook_imgs/NAF_quantities.png)

# %%
class NAFNetwork(nn.Module):
    def __init__(self, state_size, action_size, layer_size):
        super(NAFNetwork, self).__init__()
        self.action_size = action_size

        self.fc_0 = nn.Linear(state_size, layer_size)
        self.fc_1 = nn.Linear(layer_size, layer_size)
        self.fc_2 = nn.Linear(layer_size, layer_size)
        
        # TODO: make output layers
        # HINT: The number of entries in a (not-strictly) lower-triangular n x n matrix is: n * (n + 1) / 2
        self.mu_head = nn.Linear(layer_size, action_size)
        self.v_head = nn.Linear(layer_size, 1)
        self.mat_head = nn.Linear(layer_size, int(self.action_size*(self.action_size+1)/2))

    def forward(self, state, action=None):
        """
        Forward pass of Normalized Advantage Function
        Returns the noisy exploration action, Q(s, a), V(s), and the greedy, non-noisy action
        """
        # get latent representation
        x = torch.relu(self.fc_0(state))
        x = torch.relu(self.fc_1(x))
        x = torch.relu(self.fc_2(x))
        
        # TODO predict the action mu, the value v and the matrix entries
        greedy_action = self.mu_head(x)
        V = self.v_head(x)
        entries = torch.tanh(self.mat_head(x))

        greedy_action = greedy_action.unsqueeze(-1)
        
        # TODO: calculate P
        # create empty lower-triangular matrix
        L = torch.zeros((state.shape[0], self.action_size, self.action_size)).to(DEVICE)

        # get lower triagular indices
        tril_indices = torch.tril_indices(row=self.action_size, col=self.action_size, offset=0)  

        # fill matrix with entries
        L[:, tril_indices[0], tril_indices[1]] = entries
        # exponentiate diagonal terms
        L.diagonal(dim1=1,dim2=2).exp_()

        # calculate state-dependent, positive-definite square matrix
        P = L*L.transpose(2, 1)
        
        # if an action is given (during batch update), calculate Q
        Q = None
        if action is not None:
            # calculate Advantage:
            A = (-0.5 * torch.matmul(torch.matmul((action.unsqueeze(-1) - greedy_action).transpose(2, 1), P), (action.unsqueeze(-1) - greedy_action))).squeeze(-1)
            Q = A + V

        # add noise to the greedy action, for exploration in continuous action space
        #dist = MultivariateNormal(greedy_action.squeeze(-1), torch.inverse(P))
        dist = MultivariateNormal(greedy_action.squeeze(-1), torch.eye(2))
        action = dist.sample()
        noisy_action = torch.clamp(action, min=-2, max=2)
        
        return noisy_action, Q, V, greedy_action

# %% [markdown]
# Next, we make a class for the NAF agent, that will hold an instance of the above class for the neural network. The agent also implements an update method that updates the parameters of the neural network networka and a rollout method. Fortunately, the NAF update is straightforward, since it directly minimizes the TD error. **In the below cell, in the `update` method, compute the loss as described in the algorithm**. The update method alongside the rollout method essentially implement the entire NAF algorithm:
# ![NAF algorithm](notebook_imgs/NAF_algo.png)

# %%
class NAFAgent:
    def __init__(self, n_states, n_actions, buffer, net_size, gamma, tau, lr):
        """
        @param n_states: The dimensionality of the state space
        @param n_actions: The dimensionality of the action space
        @param buffer: An instance of a replay buffer
        @param net_size: The width of the NAF network layers
        @param gamma: The discount rate
        @param tau: The soft/polyak target network update rate
        @param lr: The learning rate
        """
        self.buffer = buffer
        self.loss_fn = nn.SmoothL1Loss()
        self.update_counter = 0
        self.GAMMA = gamma
        self.TAU = tau
        self.LR = lr
        self.loss_hist = []

        # main network
        self.naf_net = NAFNetwork(
            state_size=n_states,
            action_size=n_actions,
            layer_size=net_size,
        )
        self.naf_net.to(DEVICE)

        # target network
        self.target_net = NAFNetwork(
            state_size=n_states,
            action_size=n_actions,
            layer_size=net_size,
        )
        self.target_net.to(DEVICE)
        self.target_net.load_state_dict(self.naf_net.state_dict())

        self.optim = Adam(self.naf_net.parameters(), lr=self.LR)
        
    def rollout(self, env, episode, mode="train"):
        """
        Runs one episode and does a batch update after each step.
        """
        obs, info = env.reset()
        #obs = env.reset()
        done = False
        truncated = False
        total_reward = 0

        while not (done or truncated):
            if mode == "train":
                action, _, _, _ = self.naf_net(torch.from_numpy(obs).unsqueeze(0).to(DEVICE).to(torch.float32))
            elif mode == "eval":
                _, _, _, action = self.naf_net(torch.from_numpy(obs).to(DEVICE).to(torch.float32))
            else:
                raise ValueError(f"Invalid mode 'mode' given!")
            
            action = transform_action(action.squeeze(0), env)
            
            new_obs, reward, done, truncated, deviceinfo = env.step(action)
            #new_obs, reward, done, truncated = env.step(action)

            total_reward += reward
            
            if mode == "train":
                self.buffer.add(obs, action, reward, new_obs, done)
                self.update()

            if done or truncated:
                print(f"Total reward {mode} episode {episode}: {total_reward}")
                return total_reward
            
            obs = new_obs

    def update(self):
        """
        Updates the neural network based on a batch of experiences sampled from the replay buffer.
        """
        if len(self.buffer) < self.buffer.batch_size:
            return

        states, actions, rewards, next_states, dones = self.buffer.sample()
        self.optim.zero_grad()
        
        # TODO: compute the loss
        # This involves calling self.loss_fn(Q, y)
        # ---------------------

        
        #loss = None

        with torch.no_grad():
            _, _, V_, _ = self.target_net(next_states)

        # Compute Q targets for current states 
        V_targets = rewards + (self.GAMMA * V_ * (1 - dones))
        
        # Get expected Q values from local model
        _, Q, _, _ = self.naf_net(states, actions)

        # Compute loss
        loss = self.loss_fn(Q, V_targets)
                
        # ---------------------
        loss.backward()
        self.optim.step()

        self.loss_hist.append(loss.item())
        self.update_counter += 1

        # polyak/soft target network udpate
        for target_param, current_param in zip(self.target_net.parameters(), self.naf_net.parameters()):
            target_param.data.copy_(self.TAU * current_param.data + (1.0 - self.TAU) * target_param.data)

# %% [markdown]
# Now, we just need a method that initializes the agent and runs the main trianing loop . **In the next cell, don't change anything**. You can play with the hyperparameters later, but when we highly recommend that you don't change them for now, since the ones we put for you definitly work!

# %%
def naf_algo(env): 
    # hyperparameters
    TRAIN_EPISODES = 200
    NET_SIZE = 64
    GAMMA = 0.975
    TAU = 0.0025
    LR = 0.001
    BATCH_SIZE = 128
    
    buffer = ReplayBuffer(
        buffer_size=int(1e6),
        batch_size=BATCH_SIZE,
        device=DEVICE,
    )
    
    agent = NAFAgent(
        env.observation_space.shape[0],
        env.action_space.shape[0],
        buffer,
        NET_SIZE,
        GAMMA,
        TAU,
        LR
    )
    
    # populate replay buffer with 10k random transitions
    presample_env(env, agent.buffer, 10000)

    # main loop
    training_rewards = []
    eval_rewards = []
    eval_eps = []
    for episode in range(TRAIN_EPISODES):
        tr = agent.rollout(env, episode)
        training_rewards.append(tr)

        if episode % 5 == 0:
            er = agent.rollout(env, episode, mode="eval")
            eval_rewards.append(er)
            eval_eps.append(episode)
            
    plot_loss(agent.loss_hist)
    plot_reward(training_rewards, eval_rewards, eval_eps)
    
    return agent

# %% [markdown]
# # Testing NAF on Pendulum environment
# Now, with all of this (partially boilerplate) code out of the way, its time to test our NAF agent. We use the [OpenAI Gym Pendulum environment](https://mgoulao.github.io/gym-docs/environments/classic_control/pendulum/), which is arguably one of the easiest, continuous action space environments. The agent should reach about -250 reward relatively quickly, if you've implemented everything correctly. There can still be quite some variation (i.e. between 0 and -700), depending on the random initialization of the pendulum...

# %%
pendulum_env = gym.make("Pendulum-v1")
naf_agent = naf_algo(pendulum_env)
# Out:
# Presampling done
# Total reward train episode 0: -1032.9890028036762
# Total reward eval episode 0: -1066.9832441627289
# Total reward train episode 1: -1070.768572732701
# Total reward train episode 2: -1585.7417978052813
# Total reward train episode 3: -1052.7174867891272
# Total reward train episode 4: -1409.7469167371125
# Total reward train episode 5: -1646.4409290231067
# Total reward eval episode 5: -1915.478392959994
# Total reward train episode 6: -1741.4811777455757
# Total reward train episode 7: -1521.4553434156658
# Total reward train episode 8: -1621.9162574292557
# Total reward train episode 9: -1644.4086293903647
# Total reward train episode 10: -1463.8552671503287
# Total reward eval episode 10: -1759.7208011642801
# Total reward train episode 11: -1276.00502148959
# Total reward train episode 12: -1371.816005952665
# Total reward train episode 13: -1381.381425611932
# Total reward train episode 14: -1081.3612544229613
# Total reward train episode 15: -965.3659767943441
# Total reward eval episode 15: -1097.9791422510602
# Total reward train episode 16: -1070.821320405074
# Total reward train episode 17: -944.5268230314122
# Total reward train episode 18: -939.7374019741974
# Total reward train episode 19: -1030.274947241589
# Total reward train episode 20: -1016.0479762423101
# Total reward eval episode 20: -794.4998684919593
# Total reward train episode 21: -709.6900801525902
# Total reward train episode 22: -692.0824508164432
# Total reward train episode 23: -792.786745661163
# Total reward train episode 24: -899.1555872855446
# Total reward train episode 25: -757.0918859604491
# Total reward eval episode 25: -410.6213344429695
# Total reward train episode 26: -896.685523647542
# Total reward train episode 27: -897.9083181556381
# Total reward train episode 28: -888.2400027889729
# Total reward train episode 29: -948.4440539465055
# Total reward train episode 30: -850.9779856598973
# Total reward eval episode 30: -162.5597194666408
# Total reward train episode 31: -650.489812598437
# Total reward train episode 32: -901.5523012972765
# Total reward train episode 33: -886.2514390492184
# Total reward train episode 34: -875.8759057961569
# Total reward train episode 35: -882.3525780270361
# Total reward eval episode 35: -138.05740888220203
# Total reward train episode 36: -763.1007142512389
# Total reward train episode 37: -724.9433439851261
# Total reward train episode 38: -820.9898455850545
# Total reward train episode 39: -614.4690726768619
# Total reward train episode 40: -632.0185078516449
# Total reward eval episode 40: -13.762101458217359
# Total reward train episode 41: -638.3153865421319
# Total reward train episode 42: -527.8792827277122
# Total reward train episode 43: -435.3128649374343
# Total reward train episode 44: -259.22403805109724
# Total reward train episode 45: -144.19463713102058
# Total reward eval episode 45: -258.42357379654817
# Total reward train episode 46: -645.8935465803984
# Total reward train episode 47: -267.814159232639
# Total reward train episode 48: -142.09216832802113
# Total reward train episode 49: -139.9809272613599
# Total reward train episode 50: -137.1953008654886
# Total reward eval episode 50: -7.232918232102896
# Total reward train episode 51: -258.9910966525972
# Total reward train episode 52: -8.617606571700836
# Total reward train episode 53: -135.12205792974333
# Total reward train episode 54: -309.09936882409227
# Total reward train episode 55: -253.21697427672635
# Total reward eval episode 55: -273.46604236642
# Total reward train episode 56: -132.21343640472827
# Total reward train episode 57: -248.59309424838585
# Total reward train episode 58: -126.63981191759298
# Total reward train episode 59: -352.10968742710526
# Total reward train episode 60: -136.66230313493506
# Total reward eval episode 60: -126.18904649684943
# Total reward train episode 61: -253.2597079397312
# Total reward train episode 62: -123.72215441067874
# Total reward train episode 63: -133.91220347634535
# Total reward train episode 64: -249.9887662265306
# Total reward train episode 65: -362.62371278395204
# Total reward eval episode 65: -124.82770256884913
# Total reward train episode 66: -247.74162489128634
# Total reward train episode 67: -367.5578337086724
# Total reward train episode 68: -354.7657882966247
# Total reward train episode 69: -131.67624915250985
# Total reward train episode 70: -132.84913841873768
# Total reward eval episode 70: -243.4412236199529
# Total reward train episode 71: -357.2392399542136
# Total reward train episode 72: -8.578468312378963
# Total reward train episode 73: -250.43860564470612
# Total reward train episode 74: -251.09006804137266
# Total reward train episode 75: -131.91253237237692
# Total reward eval episode 75: -122.4118086365419
# Total reward train episode 76: -311.2191346350742
# Total reward train episode 77: -128.91732258589835
# Total reward train episode 78: -126.56125326108295
# Total reward train episode 79: -131.99260011594748
# Total reward train episode 80: -125.91305832207985
# Total reward eval episode 80: -127.5653141984777
# Total reward train episode 81: -118.36553652376554
# Total reward train episode 82: -3.7726812181949145
# Total reward train episode 83: -313.207098029257
# Total reward train episode 84: -5.132163008661268
# Total reward train episode 85: -368.1371065834627
# Total reward eval episode 85: -121.63336449418276
# Total reward train episode 86: -4.434270954311481
# Total reward train episode 87: -127.28438945987047
# Total reward train episode 88: -117.33430140631611
# Total reward train episode 89: -130.39455248777512
# Total reward train episode 90: -237.2327607807329
# Total reward eval episode 90: -126.97245547491488
# Total reward train episode 91: -254.50556612135264
# Total reward train episode 92: -122.33171915573276
# Total reward train episode 93: -126.92645474494385
# Total reward train episode 94: -375.2128062854107
# Total reward train episode 95: -262.09263595427615
# Total reward eval episode 95: -120.69333927775722
# Total reward train episode 96: -132.5625463798711
# Total reward train episode 97: -234.88347279506374
# Total reward train episode 98: -131.89715145523252
# Total reward train episode 99: -258.1834961271843
# Total reward train episode 100: -468.64533996985665
# Total reward eval episode 100: -0.3382129573215612
# Total reward train episode 101: -262.0901297160686
# Total reward train episode 102: -131.34305062728683
# Total reward train episode 103: -336.2501433450077
# Total reward train episode 104: -127.41734693739234
# Total reward train episode 105: -125.93952246762345
# Total reward eval episode 105: -240.52354527632147
# Total reward train episode 106: -122.19939013240219
# Total reward train episode 107: -382.4221939501224
# Total reward train episode 108: -380.2482166441876
# Total reward train episode 109: -252.417683676442
# Total reward train episode 110: -254.5859935542209
# Total reward eval episode 110: -250.98013352094844
# Total reward train episode 111: -259.7675499515678
# Total reward train episode 112: -259.4933917425929
# Total reward train episode 113: -264.61821326108515
# Total reward train episode 114: -273.08244579987945
# Total reward train episode 115: -355.4605050133901
# Total reward eval episode 115: -3.6958405569702917
# Total reward train episode 116: -124.14312585217775
# Total reward train episode 117: -128.47859362714047
# Total reward train episode 118: -137.805463623186
# Total reward train episode 119: -129.79974188845873
# Total reward train episode 120: -130.2664457229736
# Total reward eval episode 120: -374.32784680872817
# Total reward train episode 121: -262.74661455635055
# Total reward train episode 122: -367.5055653835758
# Total reward train episode 123: -381.8236683787097
# Total reward train episode 124: -389.48128909547046
# Total reward train episode 125: -128.49645286074025
# Total reward eval episode 125: -235.5482221098208
# Total reward train episode 126: -358.6022920325462
# Total reward train episode 127: -400.84007563001313
# Total reward train episode 128: -239.7038188895457
# Total reward train episode 129: -133.28942518547208
# Total reward train episode 130: -136.78843580276168
# Total reward eval episode 130: -1.935782005834282
# Total reward train episode 131: -142.99610789636986
# Total reward train episode 132: -371.1054996749075
# Total reward train episode 133: -246.2000947854692
# Total reward train episode 134: -269.89333685679946
# Total reward train episode 135: -255.61451380242002
# Total reward eval episode 135: -129.7778683941708
# Total reward train episode 136: -138.8616807697797
# Total reward train episode 137: -407.29086910527406
# Total reward train episode 138: -340.13298206196265
# Total reward train episode 139: -365.71196644307105
# Total reward train episode 140: -261.7146658055729
# Total reward eval episode 140: -119.34668696276626
# Total reward train episode 141: -370.2651422715622
# Total reward train episode 142: -367.3164467215171
# Total reward train episode 143: -271.1486786191744
# Total reward train episode 144: -492.6595402987902
# Total reward train episode 145: -394.8541866924587
# Total reward eval episode 145: -122.93455319406063
# Total reward train episode 146: -259.9755729173307
# Total reward train episode 147: -267.65239287390176
# Total reward train episode 148: -388.2087759484534
# Total reward train episode 149: -273.29667474764256
# Total reward train episode 150: -567.7240080080749
# Total reward eval episode 150: -134.99144041446243
# Total reward train episode 151: -517.2221097369589
# Total reward train episode 152: -518.2389430150963
# Total reward train episode 153: -140.28210039755487
# Total reward train episode 154: -145.65782620273336
# Total reward train episode 155: -268.8127781075072
# Total reward eval episode 155: -4.367804545487772
# Total reward train episode 156: -269.0404376711792
# Total reward train episode 157: -396.4141212319006
# Total reward train episode 158: -388.237799472392
# Total reward train episode 159: -505.488557861198
# Total reward train episode 160: -423.3466900196883
# Total reward eval episode 160: -238.7144400818159
# Total reward train episode 161: -386.0270878569385
# Total reward train episode 162: -398.3753156408107
# Total reward train episode 163: -518.6860221676842
# Total reward train episode 164: -267.52176783266344
# Total reward train episode 165: -268.1381019500318
# Total reward eval episode 165: -247.16864458728594
# Total reward train episode 166: -393.16691013236897
# Total reward train episode 167: -515.7445852128003
# Total reward train episode 168: -301.4835104661928
# Total reward train episode 169: -627.8166304788499
# Total reward train episode 170: -386.93309432886093
# Total reward eval episode 170: -122.33460366894941
# Total reward train episode 171: -502.53199240723046
# Total reward train episode 172: -511.77082287631725
# Total reward train episode 173: -489.8493854194323
# Total reward train episode 174: -398.40327142478645
# Total reward train episode 175: -290.30561655643356
# Total reward eval episode 175: -243.53895006057024
# Total reward train episode 176: -387.74620844234704
# Total reward train episode 177: -604.5737077290742
# Total reward train episode 178: -641.5399587014975
# Total reward train episode 179: -646.470649432202
# Total reward train episode 180: -390.46444069742716
# Total reward eval episode 180: -258.24839818644796
# Total reward train episode 181: -266.9567829236773
# Total reward train episode 182: -396.03432668721643
# Total reward train episode 183: -514.165555384114
# Total reward train episode 184: -326.60805266917805
# Total reward train episode 185: -509.0074380048751
# Total reward eval episode 185: -126.62516019787815
# Total reward train episode 186: -396.34572028815097
# Total reward train episode 187: -384.3001925742061
# Total reward train episode 188: -390.06182137419495
# Total reward train episode 189: -266.026115578944
# Total reward train episode 190: -397.3164918916619
# Total reward eval episode 190: -139.0681275926503
# Total reward train episode 191: -289.31939250578506
# Total reward train episode 192: -511.6231884400508
# Total reward train episode 193: -397.83190167741986
# Total reward train episode 194: -509.18951487389984
# Total reward train episode 195: -391.2569178192017
# Total reward eval episode 195: -348.87792663821716
# Total reward train episode 196: -545.8614495725957
# Total reward train episode 197: -399.4527852196571
# Total reward train episode 198: -436.1277154520319
# Total reward train episode 199: -525.530319300431

# %% [markdown]
# ### Continue with the next part of the assignment only when your NAF implementation maintains between 0 and -700 reward on the pendulum environment!
# Once the NAF agent reaches acceptable performance on the pendulum environment, explore the effect of exploration noise. In the NAF paper in section 8.2, the authors describe how to use the matrix $P$ from the advantage term for adaptive noise generation. Assuming you used simple Gaussian noise so far, go back to the the forward pass of the neural network and implement adaptive noise instead. Do you observe a considerable difference on the Pendulum environment when using adaptive noise?

# %% [markdown]
# # Multigoal environment
# Now, we turn to a more interesting but still toy example, the "multigoal" environment introduced in the Soft Q-Learning paper. This environment features four goals (the stars in the below image) the agent can navigate to. The observation is the current position, the actions are 2D velocities to apply to the agent. The agent always starts at the center (plus some small random offset). The reward is the distance to the closest goal plus a small cost proportional to the squarred action sum. Consider below the plot of the reward function evaluated at a fine grid of locations for further intuition:
# ![multigoal env](notebook_imgs/multigoal-env-reward.png)

# %% [markdown]
# # TASK: Draw on a paper a [contour plot](https://se.mathworks.com/help/examples/graphics/win64/DisplayContourLabelsExample_01.png) of what you think NAF's value function will look like, evaluate at 2D locations in the environment as done with the reward function above. Keep the paper for later comparison with the actual value function.

# %% [markdown]
# ...

# %% [markdown]
# # TASK: Also draw the trajectories that you think NAF's policy will generate. Keep the paper for later comparison with actual trajectories generated by the policy.

# %% [markdown]
# ...

# %%
multigoal_env = MultiGoalEnv()
naf_agent = naf_algo(multigoal_env)
# Out:
# Presampling done
# Total reward train episode 0: -16119.043900585373
# Total reward eval episode 0: -17706.934225174187
# Total reward train episode 1: -11959.20992118076
# Total reward train episode 2: -2886.272155252884
# Total reward train episode 3: -3728.6397743205744
# Total reward train episode 4: -3918.4250034731144
# Total reward train episode 5: -991.763351197834
# Total reward eval episode 5: -335.68072295995677
# Total reward train episode 6: -4428.755219930559
# Total reward train episode 7: -3769.9526296393915
# Total reward train episode 8: -4221.307559367134
# Total reward train episode 9: -3712.4193618561203
# Total reward train episode 10: -3765.63694034379
# Total reward eval episode 10: -358.67393062770685
# Total reward train episode 11: -3535.2603715125974
# Total reward train episode 12: -3884.5468484547473
# Total reward train episode 13: -3692.174358340625
# Total reward train episode 14: -3445.0879839403815
# Total reward train episode 15: -3729.1039668846784
# Total reward eval episode 15: -143.56214552936376
# Total reward train episode 16: -3529.1636874376295
# Total reward train episode 17: -3953.803899222203
# Total reward train episode 18: -3654.048476046363
# Total reward train episode 19: -4069.922180162779
# Total reward train episode 20: -3707.8256309315066
# Total reward eval episode 20: -226.38853447627122
# Total reward train episode 21: -3635.4620114309078
# Total reward train episode 22: -3499.6282450513036
# Total reward train episode 23: -3869.9313643251367
# Total reward train episode 24: -3900.6988716428814
# Total reward train episode 25: -2847.7623962694574
# Total reward eval episode 25: -443.95600645849925
# Total reward train episode 26: -3128.9973370583207
# Total reward train episode 27: -3817.1774412416694
# Total reward train episode 28: -3961.6340795112064
# Total reward train episode 29: -3864.7617510268
# Total reward train episode 30: -3570.039512811288
# Total reward eval episode 30: -208.22904369986978
# Total reward train episode 31: -3735.518658030228
# Total reward train episode 32: -3469.6835797018675
# Total reward train episode 33: -3931.3627719193455
# Total reward train episode 34: -3672.3154294501915
# Total reward train episode 35: -3597.568599584951
# Total reward eval episode 35: -278.16528198373595
# Total reward train episode 36: -3524.0309422947003
# Total reward train episode 37: -3838.554077857775
# Total reward train episode 38: -3656.5757179145985
# Total reward train episode 39: -3638.9383446704524
# Total reward train episode 40: -2331.958616870235
# Total reward eval episode 40: -189.26356267001273
# Total reward train episode 41: -1623.543142155614
# Total reward train episode 42: -3622.753130242446
# Total reward train episode 43: -3674.6829073434915
# Total reward train episode 44: -3692.0371170196418
# Total reward train episode 45: -3959.5330278573706
# Total reward eval episode 45: -355.1684952325398
# Total reward train episode 46: -4134.364523376732
# Total reward train episode 47: -3792.2486441289107
# Total reward train episode 48: -3984.0830040708584
# Total reward train episode 49: -3226.844818327649
# Total reward train episode 50: -3715.2113677128723
# Total reward eval episode 50: -276.87478547383535
# Total reward train episode 51: -3532.4444476034478
# Total reward train episode 52: -3374.195021764008
# Total reward train episode 53: -3858.300246209253
# Total reward train episode 54: -3416.4826701702154
# Total reward train episode 55: -3680.3910865438556
# Total reward eval episode 55: -216.94923329788227
# Total reward train episode 56: -3557.8997538273325
# Total reward train episode 57: -3736.4842523160146
# Total reward train episode 58: -3566.2532420593952
# Total reward train episode 59: -3921.513789490592
# Total reward train episode 60: -3581.7224198248505
# Total reward eval episode 60: -341.9344599260108
# Total reward train episode 61: -3891.7505689536456
# Total reward train episode 62: -4029.113464421942
# Total reward train episode 63: -3736.7858512979305
# Total reward train episode 64: -3844.7683679627175
# Total reward train episode 65: -3808.571332904668
# Total reward eval episode 65: -183.15020436410785
# Total reward train episode 66: -3351.1130537212425
# Total reward train episode 67: -3620.3323985786637
# Total reward train episode 68: -3735.2767022270486
# Total reward train episode 69: -3656.420788825865
# Total reward train episode 70: -3621.061708717954
# Total reward eval episode 70: -165.97840110745165
# Total reward train episode 71: -3541.390760099586
# Total reward train episode 72: -3888.219798948336
# Total reward train episode 73: -3975.917178209466
# Total reward train episode 74: -3703.7707895843077
# Total reward train episode 75: -3946.0558591327467
# Total reward eval episode 75: -157.1873702280815
# Total reward train episode 76: -3679.678231740319
# Total reward train episode 77: -3775.635306997992
# Total reward train episode 78: -3417.584466522795
# Total reward train episode 79: -3648.868553025352
# Total reward train episode 80: -3867.808810610374
# Total reward eval episode 80: -241.36907925232924
# Total reward train episode 81: -3561.205371313751
# Total reward train episode 82: -3973.491681657132
# Total reward train episode 83: -4078.624682763433
# Total reward train episode 84: -4049.502263576091
# Total reward train episode 85: -3514.419539799942
# Total reward eval episode 85: -254.14636408389984
# Total reward train episode 86: -3720.0703574987824
# Total reward train episode 87: -3650.076962543517
# Total reward train episode 88: -786.731436828157
# Total reward train episode 89: -3789.1273884006305
# Total reward train episode 90: -3849.2784983346933
# Total reward eval episode 90: -290.34957998414893
# Total reward train episode 91: -3298.620362916868
# Total reward train episode 92: -3783.422227021853
# Total reward train episode 93: -3526.366750657282
# Total reward train episode 94: -3298.829834234116
# Total reward train episode 95: -3441.2129032394396
# Total reward eval episode 95: -210.44997512174314
# Total reward train episode 96: -3633.3088205679196
# Total reward train episode 97: -532.3201479865403
# Total reward train episode 98: -3849.649159618762
# Total reward train episode 99: -3421.6070164563653
# Total reward train episode 100: -3763.66730374088
# Total reward eval episode 100: -352.8220078239744
# Total reward train episode 101: -3465.0535741820354
# Total reward train episode 102: -3916.9469191927515
# Total reward train episode 103: -3827.6690622786023
# Total reward train episode 104: -3678.5050561214593
# Total reward train episode 105: -3318.510287161477
# Total reward eval episode 105: -213.81792681988088
# Total reward train episode 106: -3704.852464603666
# Total reward train episode 107: -4056.3360963071505
# Total reward train episode 108: -3414.7636199470844
# Total reward train episode 109: -3665.5769678717156
# Total reward train episode 110: -3465.2419499513876
# Total reward eval episode 110: -171.96186700801937
# Total reward train episode 111: -4092.668979422318
# Total reward train episode 112: -3709.1448468178382
# Total reward train episode 113: -3456.6708769174516
# Total reward train episode 114: -3697.163534404571
# Total reward train episode 115: -3482.8178961796993
# Total reward eval episode 115: -557.4404901965293
# Total reward train episode 116: -3666.9975791550196
# Total reward train episode 117: -3586.617094593328
# Total reward train episode 118: -3853.5886455129676
# Total reward train episode 119: -3321.9955973555857
# Total reward train episode 120: -3451.3181030663054
# Total reward eval episode 120: -170.33986172173783
# Total reward train episode 121: -3455.0369601676007
# Total reward train episode 122: -4068.410711488796
# Total reward train episode 123: -3727.2517831745013
# Total reward train episode 124: -3798.4218420977927
# Total reward train episode 125: -3905.2077834604424
# Total reward eval episode 125: -422.45871236976734
# Total reward train episode 126: -4055.299012437441
# Total reward train episode 127: -3654.396178419834
# Total reward train episode 128: -3639.5259038813965
# Total reward train episode 129: -3695.322536445038
# Total reward train episode 130: -3391.0699083816894
# Total reward eval episode 130: -349.3088369054498
# Total reward train episode 131: -3777.462492074015
# Total reward train episode 132: -798.3500568192796
# Total reward train episode 133: -3957.8853930247274
# Total reward train episode 134: -3791.154344485292
# Total reward train episode 135: -3583.6856547099997
# Total reward eval episode 135: -213.8699937435497
# Total reward train episode 136: -3622.3178136945317
# Total reward train episode 137: -3538.8053048609495
# Total reward train episode 138: -3831.0002468890398
# Total reward train episode 139: -3498.910978970333
# Total reward train episode 140: -3980.658246335542
# Total reward eval episode 140: -374.31472526255646
# Total reward train episode 141: -3771.9651577467585
# Total reward train episode 142: -3763.3996252078655
# Total reward train episode 143: -3472.207654743621
# Total reward train episode 144: -3927.355920430976
# Total reward train episode 145: -964.2920570154952
# Total reward eval episode 145: -487.04980474728586
# Total reward train episode 146: -3609.5638579484516
# Total reward train episode 147: -3604.2221445208093
# Total reward train episode 148: -3695.095164924106
# Total reward train episode 149: -3718.857014501882
# Total reward train episode 150: -3796.0074330622265
# Total reward eval episode 150: -267.0194451064895
# Total reward train episode 151: -3650.1472923319234
# Total reward train episode 152: -3703.1117620094483
# Total reward train episode 153: -3914.3074015078028
# Total reward train episode 154: -3784.785603029804
# Total reward train episode 155: -3623.06576206781
# Total reward eval episode 155: -593.7055639168085
# Total reward train episode 156: -3612.6097755577607
# Total reward train episode 157: -3688.1540411342617
# Total reward train episode 158: -3530.7691474368694
# Total reward train episode 159: -3902.4174734371204
# Total reward train episode 160: -3817.895844704864
# Total reward eval episode 160: -383.2166922717824
# Total reward train episode 161: -3588.1853806953554
# Total reward train episode 162: -3923.3832890947347
# Total reward train episode 163: -1237.9208503400232
# Total reward train episode 164: -4180.377195252878
# Total reward train episode 165: -3951.0401166747574
# Total reward eval episode 165: -581.0184803913386
# Total reward train episode 166: -3796.8545304286386
# Total reward train episode 167: -1834.380994971698
# Total reward train episode 168: -2885.6765666185534
# Total reward train episode 169: -4009.0290404351836
# Total reward train episode 170: -3443.470504804779
# Total reward eval episode 170: -171.26223609696927
# Total reward train episode 171: -4175.469048094011
# Total reward train episode 172: -3774.356254963531
# Total reward train episode 173: -3891.1681788512324
# Total reward train episode 174: -3881.77657171867
# Total reward train episode 175: -3612.8597082310503
# Total reward eval episode 175: -212.62025617043759
# Total reward train episode 176: -3782.8598547831243
# Total reward train episode 177: -3812.54280662721
# Total reward train episode 178: -3736.856260545234
# Total reward train episode 179: -4120.370391242244
# Total reward train episode 180: -3947.616034053746
# Total reward eval episode 180: -348.8918365832894
# Total reward train episode 181: -3808.186207403391
# Total reward train episode 182: -3890.457532061635
# Total reward train episode 183: -3762.195527708631
# Total reward train episode 184: -3755.7800157009688
# Total reward train episode 185: -3565.9150099182034
# Total reward eval episode 185: -269.324320783652
# Total reward train episode 186: -3785.907679446586
# Total reward train episode 187: -3414.3237117122335
# Total reward train episode 188: -3699.7381319808883
# Total reward train episode 189: -3818.2879446508173
# Total reward train episode 190: -3561.107440085378
# Total reward eval episode 190: -313.1166834260218
# Total reward train episode 191: -3772.146689869213
# Total reward train episode 192: -941.6349962885769
# Total reward train episode 193: -3412.1794755231945
# Total reward train episode 194: -3990.894930809044
# Total reward train episode 195: -3897.2422577937546
# Total reward eval episode 195: -187.41362146271766
# Total reward train episode 196: -3703.143072420984
# Total reward train episode 197: -4017.8842621105778
# Total reward train episode 198: -4003.218286646689
# Total reward train episode 199: -3686.2555995826256

# %% [markdown]
# # Analyze the reward and loss plots. Explain the result.

# %% [markdown]
# The algorithm converges after a fairly small number of episodes. The evaluation reward is higher since during evaluation it is taking the greedy action (no exploration).

# %% [markdown]
# # Visualizing the value function
# In addition to the the loss plot and reward plot above, it can be helpfull to visualize the learned value function and or policy, to understand better what the agent learned. This is often straightforward in 2D environments, since a small 2D grid is still managable in terms of compute. As such, **visualize the value function learned by the NAF agent on the multigoal environment**. Does NAF's learned value function look similar to what you drew on the paper? Can you explain why the learned value function looks the way it does?

# %% [markdown]
# In the NAF paper they mention that their approach corresponds to "doing variational inference to fit a Gaussian to a distribution, and it has mode-seeking behavior". So at each state it is approximating the value function according to a Gaussian. Since the underlying reward function corresponds to 4 Gaussians (or at least close to it), NAF should be able to learn this.

# %%
# YOUR CODE HERE
import numpy as np
import matplotlib.pyplot as plt

size = 10
xlist = torch.from_numpy(np.linspace(-size, size, 100))
ylist = torch.from_numpy(np.linspace(-size, size, 100))

img = np.zeros((100,100))

for xi, x in enumerate(xlist):
  for yi, y in enumerate(ylist):
    _, _, v, _ = naf_agent.naf_net(torch.Tensor([x, y]).to(DEVICE))
    img[xi ,yi] = v.item()


plt.imshow(img)

# %% [markdown]
# ...

# %% [markdown]
# # Visualizing trajectories
# In addition to the value function, we can inspect the trajectories generated by the policy. **Collect, plot and analyze some (10 - 50) trajectories from the policy**. Are the agent's trajectory similar to what you drew on the paper? Explain the result.

# %%
def collect_naf_trajectory(env, agent):
    state_hist = []
    
    obs, info = env.reset()
    done = False
    truncated = False
    total_reward = 0
    
    while not (done or truncated):
        _, _, _, action = agent.naf_net(torch.from_numpy(obs).to(DEVICE).to(torch.float32))
        action = transform_action(action.squeeze(0), env)
        
        new_obs, reward, done, truncated, info = env.step(action)
        total_reward += reward
        
        if done or truncated:
            break
        
        state_hist.append(obs)
        obs = new_obs
    return np.array(state_hist)

# %%
multigoal_env.init_sigma = 0.4  # we increase the reset noise, so we get a bit more diverse starting positions...
for e in range(20):
    obs_hist = collect_naf_trajectory(multigoal_env, naf_agent)
    plt.plot(obs_hist[:,0], obs_hist[:, 1], marker="o", markersize=4)
    
for goal in multigoal_env.goal_positions:
    plt.scatter(goal[0], goal[1], marker="*", s=200, c="r")

plt.xlim(multigoal_env.xlim + np.array([-0.3, 0.3]))
plt.ylim(multigoal_env.ylim + np.array([-0.3, 0.3]))
plt.show()
# YOUR CODE HERE

# %% [markdown]
# ...

# %% [markdown]
# # Soft Q-Learning
#
#
# We now turn to the second algorithm we learned about that can deal with continuous state and action spaces: Soft Q-learning (SQL). SQL is based on two neural networks, one for the $Q$-function and one for the policy. These are plain MLPs, hence this time you don't have to implement the neural network. However, you must initialize these networks with the correct input and output sizes. Thus, **in the `init` method in the next cell, set the `q_in_size`, `q_out_size`, `asvgd_noise_size`, `pi_in_size`, and `pi_out_size` variables**. These are passed to the respective neural networks initalizations.
#
# Further, you will implement the update of the $Q$-function approximating neural network. This is relatively straightforward and based on the TD-error. **In the next cell, in the `td_update` method, calculate the loss for the $Q$-approximating network**. For this, you need to implement and consider the following equations. The soft value function:
# ![sql_vsoft](notebook_imgs/SQL_v_soft.png)
# The soft value function's empirical estimate:
# ![sql_empirical_vsoft](notebook_imgs/SQL_empirical_v_soft.png)
# And the minimization objective:
# ![sql_JQ](notebook_imgs/SQL_jq.png)
# Note, that $\hat{Q}^{\bar\theta}_{\text{soft}} = r_t + \gamma \mathbb{E}_{s_{t+1}\sim p_s}[ V^{\bar\theta}_{\text{soft}}(s_{t+1}) ]$ and that $\bar\theta$ refers to the target network parameter.
#
# We implement the update of the policy network for you, because itrelies on a method not covered in the course, the Amortized Stein Variational Gradient Descent (ASVGD). ASVGD has gained increasing popularity in SOTA research and provides an interesting alternative to sampling methods like Markov Chain Monte Carlo or Metropolis Hastings. ASVGD moves a set of random particles such that, after convergence, they act like samples from the distribution of interest, and only requires access to the unnormalized density. You can take a look how this is implemented and how it updates the policy network in the `asvgd_update` method. If you are interested, we encourage you to take a look at the official [project website](https://www.cs.utexas.edu/~qlearning/project.html?p=svgd).

# %%
class SQLAgent:
    """
    SQL agent, https://arxiv.org/pdf/1702.08165.pdf
    """
    def __init__(self,
                 n_states,
                 n_actions,
                 buffer,
                 net_size,
                 gamma,
                 q_lr,
                 asvgd_lr,
                 hard_freq,
                 reward_scale,
                 n_particles,
                 ):
        """
        @param n_states: The dimensionality of the state space
        @param n_actions: The dimensionality of the action space
        @param buffer: An instance of a replay buffer
        @param net_size: The width of the NAF network layers
        @param gamma: The discount rate
        @param q_lr: The learning rate for the q network
        @param asvgd_lr: The learnign rate for the policy network
        @param hard_freq: The hard update frequency of the q target network
        @param reward_scale: The scale of the reward signal
        @param n_particles: The number of particles used by ASVGD
        """
        self.n_states = n_states
        self.n_actions = n_actions
        self.buffer = buffer
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.q_update_counter = 0
        self.GAMMA = gamma
        self.HARD_FREQ = hard_freq
        self.loss_hist = []
        self.reward_scale = reward_scale
        self.noise_gen = OUNoise(n_actions)
        self.n_particles = n_particles
        
        #  TODO: set these to the right values (these are all integers...)
        # ---------------------
        q_in_size = n_states + n_actions
        q_out_size = 1
        asvgd_noise_size = n_actions
        pi_in_size = asvgd_noise_size + n_states
        pi_out_size = n_actions
        # ---------------------

        # Q network
        self.q_net = MLP(
            in_size=q_in_size,
            out_size=q_out_size,
            layer_size=net_size,
        ).to(DEVICE)

        # target Q network
        self.target_q_net = MLP(
            in_size=q_in_size,
            out_size=q_out_size,
            layer_size=net_size,
        ).to(DEVICE)
        self.target_q_net.to(DEVICE)
        self.target_q_net.load_state_dict(self.q_net.state_dict())

        # policy sampling network
        self.pi_net = MLP(
            in_size=pi_in_size,
            out_size=pi_out_size,
            layer_size=net_size,
        ).to(DEVICE)
        self.asvgd_noise_size = asvgd_noise_size

        self.q_optim = Adam(self.q_net.parameters(), lr=q_lr, weight_decay=0.01)
        self.asvgd_optim = Adam(self.pi_net.parameters(), lr=asvgd_lr)

    def td_update(self):
        """
        Updates the Q network based on a batch of experiences drawn uniformly from the replay buffer
        """
        if len(self.buffer.memory) < self.buffer.batch_size:
            return

        states, actions, rewards, next_states, dones = self.buffer.sample()
        self.q_optim.zero_grad()

        # predict q for batch
        q = self.q_net.forward(torch.cat((states, actions), dim=1))

        with torch.no_grad():
            # TODO, calculate the 'target' aka 'desired' value J_Q(\theta), so that we can minimize the loss 
            # between q and the target
            # ---------------------
            
            proposal_actions = torch.tensor(
                np.random.uniform(
                    -1,
                    1,
                    size=(next_states.shape[0], self.n_actions)
                )
            ).to(torch.float32).to(DEVICE)
            q_soft = self.target_q_net.forward(torch.cat((next_states, proposal_actions), dim=1))

            v_soft = torch.logsumexp(q_soft, dim=1).unsqueeze(1)

            v_soft += torch.log(torch.tensor([2]).to(DEVICE)) * self.n_actions

            target = self.reward_scale * rewards + self.GAMMA * v_soft * (1-dones)

        loss = self.loss_fn(q, target)
        loss.backward()
        self.q_optim.step()
        self.loss_hist.append(loss.item())

        self.q_update_counter += 1

        # hard target network update
        if self.q_update_counter % self.HARD_FREQ == 0:
            self.target_q_net.load_state_dict(self.q_net.state_dict())
            
    def act(self, state):
        """
        Helper function that constructs the input to the policy network.
        This is done slightly differently depending on on the shape of the state tensor.
        """
        if state.shape[0] == 1:
            # environment interaction
            zeta = torch.rand(self.n_particles, self.asvgd_noise_size).to(DEVICE)
            state = state.repeat(self.n_particles, 1)
            inp = torch.cat((state, zeta), dim=1)
        else:
            # batch update
            zeta = torch.rand(state.shape[0], self.n_particles, self.asvgd_noise_size).to(DEVICE)
            state = state.repeat(self.n_particles, 1, 1).movedim(1, 0)
            inp = torch.cat((state, zeta), dim=2)

        action = self.pi_net.forward(inp.to(torch.float32))

        return action
    
    def rollout(self, env, episode, mode="train"):
        """
        Runs one episode and does a batch update after each step.
        """
        obs, info = env.reset()
        done = False
        truncated = False
        total_reward = 0

        while not (done or truncated):
            a = self.act(torch.from_numpy(obs).unsqueeze(0).to(torch.float32).to(DEVICE))
            o_stack = obs_transform(torch.from_numpy(obs).unsqueeze(0), self.n_particles).to(torch.float32).to(DEVICE)
            q = self.q_net.forward(torch.cat((o_stack, a), dim=1))
            ind = torch.argmax(q)
            action = a[ind]

            if mode == "train":
                action += torch.from_numpy(self.noise_gen.sample()).to(DEVICE)

            action = transform_action(action, env)
            new_obs, reward, done, truncated, info = env.step(action)
            total_reward += reward

            if mode == "train":
                self.buffer.add(obs, action, reward, new_obs, done)
                self.td_update()
                self.asvgd_update()

            if done or truncated:
                print(f"Total reward {mode} episode {episode}: {total_reward}")
                return total_reward

            obs = new_obs

    def asvgd_update(self):
        """
        Updates the policy network using the ASVGD method on a batch of experiences drawn uniformly from the 
        replay buffer.
        """
        if len(self.buffer.memory) < self.buffer.batch_size:
            return

        states, actions, rewards, next_states, dones = self.buffer.sample()

        # as described in the appendix of SQL paper, we need two sets of actions
        actions = self.act(states)
        assert actions.shape == (states.shape[0], self.n_particles, self.n_actions)

        fixed_actions = self.act(states)
        fixed_actions = fixed_actions.detach()
        fixed_actions.requires_grad = True

        # target for sampler is q, aka unnormalized policy density, thanks to maximum entropy framework
        state_stack = obs_transform(states, self.n_particles).to(DEVICE)
        asvgd_target = self.q_net(torch.cat((state_stack, fixed_actions), dim=2))
        log_p = asvgd_target

        grad_log_p = torch.autograd.grad(log_p.sum().to(DEVICE), fixed_actions.to(DEVICE))[0]
        grad_log_p = grad_log_p.unsqueeze(1)

        kappa, kappa_grad = rbf_kernel2(actions, fixed_actions)
        
        # eq 13 in paper, stein gradient
        actions_grad = (1/self.n_particles) * torch.sum(kappa * grad_log_p + kappa_grad, dim=1)
        actions_grad.to(DEVICE)

        self.asvgd_optim.zero_grad()
        torch.autograd.backward(-actions, grad_tensors=actions_grad)  # this implements eq 14, chain rule backprop
        self.asvgd_optim.step()

# %% [markdown]
# With the update methods taken care of, as before, the only thing that is missing is the main loop. Also as before, we high suggest you don't change any of the hyperparameters until your SQL implementation is working.

# %%
def sql_algo(env, reward_scale, n_particles):
    # hyperparameters
    TRAIN_EPISODES = 200
    BATCH_SIZE = 64
    NET_SIZE = 128
    GAMMA = 0.99
    Q_LR = 0.001
    PI_LR = 0.0001
    HARD_FREQ = 1000
    
    buffer = ReplayBuffer(
        buffer_size=int(1e6),
        batch_size=BATCH_SIZE,
        device=DEVICE,
    )
    
    agent = SQLAgent(
        env.observation_space.shape[0],
        env.action_space.shape[0],
        buffer,
        NET_SIZE,
        GAMMA,
        Q_LR,
        PI_LR,
        HARD_FREQ,
        reward_scale,
        n_particles
    )
    
    # populate replay buffer with 10k random transitions
    presample_env(env, agent.buffer, 10000)

    # main loop
    training_rewards = []
    eval_rewards = []
    eval_eps = []
    for episode in range(TRAIN_EPISODES):        
        tr = agent.rollout(env, episode)
        training_rewards.append(tr)

        if episode % 5 == 0:
            er = agent.rollout(env, episode, mode="eval")
            eval_rewards.append(er)
            eval_eps.append(episode)
            
    plot_loss(agent.loss_hist)
    plot_reward(training_rewards, eval_rewards, eval_eps)
    
    return agent

# %% [markdown]
# # Testing SQL on Pendulum environment
# As before, we first evaluate our implementation on the pendulum environment. The algorithm should be able to reach good performance (between 0 and -700) reward within 100 episodes.

# %%
pendulum_env = gym.make("Pendulum-v1")
sql_agent = sql_algo(pendulum_env, reward_scale=10, n_particles=32)
# Out:
# Presampling done
# Total reward train episode 0: -1182.6058545804517
# Total reward eval episode 0: -1190.107093277513
# Total reward train episode 1: -1347.6157162475406
# Total reward train episode 2: -1034.073041473409
# Total reward train episode 3: -1649.8210070493558
# Total reward train episode 4: -1133.7849529113194
# Total reward train episode 5: -1777.5811962535245
# Total reward eval episode 5: -1610.9542991633202
# Total reward train episode 6: -1711.4520747214588
# Total reward train episode 7: -1567.9988146814835
# Total reward train episode 8: -1576.7962898159815
# Total reward train episode 9: -1626.968022240467
# Total reward train episode 10: -1706.4093759686966
# Total reward eval episode 10: -1538.3684098604494
# Total reward train episode 11: -1448.2859627733333
# Total reward train episode 12: -1523.3984014866412
# Total reward train episode 13: -1581.9134163407448
# Total reward train episode 14: -1599.7728284928362
# Total reward train episode 15: -1586.095687042118
# Total reward eval episode 15: -1456.9332168464473
# Total reward train episode 16: -1393.6551546952178
# Total reward train episode 17: -1565.2559397594937
# Total reward train episode 18: -1619.9053675027371
# Total reward train episode 19: -1577.4376328677026
# Total reward train episode 20: -1462.4666200210052
# Total reward eval episode 20: -1526.9940894241718
# Total reward train episode 21: -1510.94385957688
# Total reward train episode 22: -1459.103525566539
# Total reward train episode 23: -1453.3740913573517
# Total reward train episode 24: -1387.3076021646018
# Total reward train episode 25: -1302.376766024603
# Total reward eval episode 25: -967.1562371398874
# Total reward train episode 26: -1245.623860754289
# Total reward train episode 27: -1247.7213669982154
# Total reward train episode 28: -1247.9143995331897
# Total reward train episode 29: -1318.0939875382892
# Total reward train episode 30: -1166.6012729443087
# Total reward eval episode 30: -1177.8091565145505
# Total reward train episode 31: -1038.9505582430218
# Total reward train episode 32: -936.3503814581989
# Total reward train episode 33: -1163.3058494971124
# Total reward train episode 34: -1012.2237539719991
# Total reward train episode 35: -1071.6170428164858
# Total reward eval episode 35: -1491.694238892074
# Total reward train episode 36: -972.6421968660476
# Total reward train episode 37: -805.5674866318925
# Total reward train episode 38: -947.26156345948
# Total reward train episode 39: -929.6601220162795
# Total reward train episode 40: -1054.025443404519
# Total reward eval episode 40: -944.2254767011982
# Total reward train episode 41: -811.799755502784
# Total reward train episode 42: -958.1961926219051
# Total reward train episode 43: -798.2698236485293
# Total reward train episode 44: -945.3870427795492
# Total reward train episode 45: -402.83975002121963
# Total reward eval episode 45: -799.3162098394071
# Total reward train episode 46: -679.6172697934923
# Total reward train episode 47: -1382.751801049268
# Total reward train episode 48: -914.1499398335607
# Total reward train episode 49: -396.3500729692123
# Total reward train episode 50: -799.7145789328586
# Total reward eval episode 50: -135.25275400609408
# Total reward train episode 51: -1336.9166864257556
# Total reward train episode 52: -535.7533773193979
# Total reward train episode 53: -269.19498878062416
# Total reward train episode 54: -695.5834127632837
# Total reward train episode 55: -136.91543465806495
# Total reward eval episode 55: -396.59090261787026
# Total reward train episode 56: -512.7266643857121
# Total reward train episode 57: -274.8638633766572
# Total reward train episode 58: -267.5431377497777
# Total reward train episode 59: -270.14103796307774
# Total reward train episode 60: -262.60114374159633
# Total reward eval episode 60: -131.97732405271287
# Total reward train episode 61: -446.41440892980046
# Total reward train episode 62: -357.0396127224094
# Total reward train episode 63: -251.7726200059822
# Total reward train episode 64: -392.89362099454735
# Total reward train episode 65: -137.18635862339215
# Total reward eval episode 65: -0.653078494943365
# Total reward train episode 66: -130.03486901376607
# Total reward train episode 67: -1491.0671754451619
# Total reward train episode 68: -135.19409164328886
# Total reward train episode 69: -124.55474011567645
# Total reward train episode 70: -1.1864418351095276
# Total reward eval episode 70: -132.15517287511057
# Total reward train episode 71: -133.58154883799713
# Total reward train episode 72: -244.09043149553054
# Total reward train episode 73: -268.6541142227821
# Total reward train episode 74: -265.80830208549355
# Total reward train episode 75: -114.17954898279616
# Total reward eval episode 75: -249.72976626001235
# Total reward train episode 76: -264.3523563463279
# Total reward train episode 77: -123.0929185245725
# Total reward train episode 78: -237.971863592373
# Total reward train episode 79: -239.57638876644876
# Total reward train episode 80: -119.157244736129
# Total reward eval episode 80: -119.79866769604402
# Total reward train episode 81: -121.68449141708955
# Total reward train episode 82: -128.44680257231462
# Total reward train episode 83: -127.3208189242733
# Total reward train episode 84: -3.8471577459222037
# Total reward train episode 85: -129.59051081873437
# Total reward eval episode 85: -120.78990135431316
# Total reward train episode 86: -117.3041279035634
# Total reward train episode 87: -239.2688560565672
# Total reward train episode 88: -269.3392283891802
# Total reward train episode 89: -119.64552443884882
# Total reward train episode 90: -122.08221462769022
# Total reward eval episode 90: -123.33766535056927
# Total reward train episode 91: -124.12369031714968
# Total reward train episode 92: -119.8439971652107
# Total reward train episode 93: -116.93307218215845
# Total reward train episode 94: -126.13747906812989
# Total reward train episode 95: -125.13807893159805
# Total reward eval episode 95: -122.8585564650837
# Total reward train episode 96: -125.21444666845863
# Total reward train episode 97: -127.73288911254149
# Total reward train episode 98: -119.04651096558855
# Total reward train episode 99: -127.89124925843447
# Total reward train episode 100: -113.22839482494972
# Total reward eval episode 100: -124.94919113214544
# Total reward train episode 101: -230.98154642406445
# Total reward train episode 102: -126.33107791596377
# Total reward train episode 103: -372.063404090156
# Total reward train episode 104: -238.8766392692944
# Total reward train episode 105: -126.22971798639004
# Total reward eval episode 105: -0.42669514078920656
# Total reward train episode 106: -123.8521080814992
# Total reward train episode 107: -265.21175461825715
# Total reward train episode 108: -385.7398501911997
# Total reward train episode 109: -130.9912024640273
# Total reward train episode 110: -124.2324613125829
# Total reward eval episode 110: -237.49975062827323
# Total reward train episode 111: -119.56807509480444
# Total reward train episode 112: -354.22676955708914
# Total reward train episode 113: -125.89076959287343
# Total reward train episode 114: -125.4730969092575
# Total reward train episode 115: -125.5937625872648
# Total reward eval episode 115: -237.41091469519517
# Total reward train episode 116: -123.79530352587203
# Total reward train episode 117: -123.54480338975584
# Total reward train episode 118: -0.3664807310654535
# Total reward train episode 119: -252.75808543611677
# Total reward train episode 120: -122.41673795518409
# Total reward eval episode 120: -123.76538249044415
# Total reward train episode 121: -123.87541579344793
# Total reward train episode 122: -237.31919718816764
# Total reward train episode 123: -125.2169938253173
# Total reward train episode 124: -305.9771071691257
# Total reward train episode 125: -126.41132645273629
# Total reward eval episode 125: -1491.6075151985906
# Total reward train episode 126: -1490.9099231908244
# Total reward train episode 127: -236.6216982099177
# Total reward train episode 128: -121.97657054688874
# Total reward train episode 129: -0.3091331221859365
# Total reward train episode 130: -1494.9978389946828
# Total reward eval episode 130: -121.59284756197206
# Total reward train episode 131: -2.116261188672302
# Total reward train episode 132: -120.08531366083075
# Total reward train episode 133: -387.69469713986535
# Total reward train episode 134: -248.81900962904936
# Total reward train episode 135: -0.23105904506195027
# Total reward eval episode 135: -397.1043703778034
# Total reward train episode 136: -122.83525550488487
# Total reward train episode 137: -123.95835555959675
# Total reward train episode 138: -124.40736698342008
# Total reward train episode 139: -0.7832781212255252
# Total reward train episode 140: -124.20345395142559
# Total reward eval episode 140: -269.6319195599982
# Total reward train episode 141: -126.36884941031356
# Total reward train episode 142: -362.897638015737
# Total reward train episode 143: -126.60887042168581
# Total reward train episode 144: -124.89096846259942
# Total reward train episode 145: -124.86121329603183
# Total reward eval episode 145: -126.76339460952971
# Total reward train episode 146: -245.53827339737083
# Total reward train episode 147: -412.3799643143788
# Total reward train episode 148: -124.00490676011606
# Total reward train episode 149: -244.18843057845658
# Total reward train episode 150: -123.39601972205743
# Total reward eval episode 150: -235.03857666530433
# Total reward train episode 151: -124.4694028333604
# Total reward train episode 152: -128.12310446908907
# Total reward train episode 153: -0.7717311385907394
# Total reward train episode 154: -126.13814477318464
# Total reward train episode 155: -125.14125693323712
# Total reward eval episode 155: -0.518944789545033
# Total reward train episode 156: -0.3037819379699464
# Total reward train episode 157: -127.64919299317087
# Total reward train episode 158: -126.12898762836713
# Total reward train episode 159: -126.13905293486091
# Total reward train episode 160: -119.28950957372842
# Total reward eval episode 160: -355.3159051029935
# Total reward train episode 161: -240.05914968907882
# Total reward train episode 162: -119.29541317091903
# Total reward train episode 163: -120.84985468043844
# Total reward train episode 164: -129.6880953853503
# Total reward train episode 165: -117.65278523626591
# Total reward eval episode 165: -314.0779817416944
# Total reward train episode 166: -124.209325943732
# Total reward train episode 167: -122.67918239440591
# Total reward train episode 168: -125.43190771840058
# Total reward train episode 169: -361.8955910102672
# Total reward train episode 170: -116.48265835226901
# Total reward eval episode 170: -116.87404081328611
# Total reward train episode 171: -280.32822694724405
# Total reward train episode 172: -0.2833438591889223
# Total reward train episode 173: -123.80290611396667
# Total reward train episode 174: -357.72811280688273
# Total reward train episode 175: -117.89378808732343
# Total reward eval episode 175: -123.22089255769676
# Total reward train episode 176: -124.80378253585019
# Total reward train episode 177: -128.07042165119816
# Total reward train episode 178: -114.25246761588213
# Total reward train episode 179: -244.38306485794263
# Total reward train episode 180: -116.87270322816477
# Total reward eval episode 180: -122.6469428010527
# Total reward train episode 181: -0.2797937812540965
# Total reward train episode 182: -262.7189211313938
# Total reward train episode 183: -123.6889670019312
# Total reward train episode 184: -230.3362611923533
# Total reward train episode 185: -117.86069799035232
# Total reward eval episode 185: -231.64876899305798
# Total reward train episode 186: -317.79542557529743
# Total reward train episode 187: -115.23453740280002
# Total reward train episode 188: -120.78864521339935
# Total reward train episode 189: -123.33486612520528
# Total reward train episode 190: -116.79403675108766
# Total reward eval episode 190: -113.63702352701293
# Total reward train episode 191: -121.71118884231781
# Total reward train episode 192: -122.73501888602325
# Total reward train episode 193: -328.3868817174385
# Total reward train episode 194: -118.55945304991792
# Total reward train episode 195: -118.6394656689553
# Total reward eval episode 195: -118.69347128887422
# Total reward train episode 196: -0.30644885150317575
# Total reward train episode 197: -126.20257458401612
# Total reward train episode 198: -250.05947140441273
# Total reward train episode 199: -0.349866084252505

# %% [markdown]
# # Testin SQL on Multigoal environment
# Once you have verified your SQL implementation, you can continue and test it on the multigoal environment.
#
# ## Again, draw what you think the value function learned by SQL will look like. Also draw the trajectories you think SQL will generate.
# Again keep the paper for later comparison with the actual results.

# %%
multigoal_env = MultiGoalEnv()
sql_agent = sql_algo(multigoal_env, reward_scale=1, n_particles=100)
# Out:
# Presampling done
# Total reward train episode 0: -10781.874382883976
# Total reward eval episode 0: -17044.107302206194
# Total reward train episode 1: -4107.451497443027
# Total reward train episode 2: -2773.363748094618
# Total reward train episode 3: -3278.088698582576
# Total reward train episode 4: -5870.946562055103
# Total reward train episode 5: -5715.666317448273
# Total reward eval episode 5: -995.095804397548
# Total reward train episode 6: -7233.004419822189
# Total reward train episode 7: -3747.1590852971453
# Total reward train episode 8: -3177.3397227715427
# Total reward train episode 9: -4781.111659180143
# Total reward train episode 10: -2535.3159036580873
# Total reward eval episode 10: -1117.573142700022
# Total reward train episode 11: -3452.289747857656
# Total reward train episode 12: -4582.753101938513
# Total reward train episode 13: -3289.738179626037
# Total reward train episode 14: -4044.2689772444255
# Total reward train episode 15: -4012.531612096951
# Total reward eval episode 15: -499.09236884696264
# Total reward train episode 16: -3470.9824707464736
# Total reward train episode 17: -4356.714492578475
# Total reward train episode 18: -2949.0748674086026
# Total reward train episode 19: -2916.8394203475095
# Total reward train episode 20: -3491.3396443297834
# Total reward eval episode 20: -478.6931897626172
# Total reward train episode 21: -2827.6981426300013
# Total reward train episode 22: -3253.732114698325
# Total reward train episode 23: -2838.4046962582484
# Total reward train episode 24: -2832.0769811638784
# Total reward train episode 25: -2704.4713581641818
# Total reward eval episode 25: -535.8730219266458
# Total reward train episode 26: -2767.918104183132
# Total reward train episode 27: -2897.9537935002004
# Total reward train episode 28: -3650.877027280368
# Total reward train episode 29: -3266.0644828908744
# Total reward train episode 30: -2755.6447093831393
# Total reward eval episode 30: -457.6326642445881
# Total reward train episode 31: -2114.490907372367
# Total reward train episode 32: -1620.6083476711387
# Total reward train episode 33: -2694.064367026832
# Total reward train episode 34: -2138.430247112037
# Total reward train episode 35: -3304.1132088729696
# Total reward eval episode 35: -417.76956872277685
# Total reward train episode 36: -2788.709531588149
# Total reward train episode 37: -2860.5936323180563
# Total reward train episode 38: -1639.8571473026177
# Total reward train episode 39: -2441.4374178293874
# Total reward train episode 40: -2859.961275583642
# Total reward eval episode 40: -378.20017413102244
# Total reward train episode 41: -2680.2783901447633
# Total reward train episode 42: -2934.0757179020197
# Total reward train episode 43: -2217.836872389437
# Total reward train episode 44: -2194.1462327599743
# Total reward train episode 45: -2232.2640626841876
# Total reward eval episode 45: -449.51580271548517
# Total reward train episode 46: -1911.4182630312405
# Total reward train episode 47: -2419.4468545443833
# Total reward train episode 48: -1952.8044120146458
# Total reward train episode 49: -1494.011769496241
# Total reward train episode 50: -2170.775325278031
# Total reward eval episode 50: -203.46160536027216
# Total reward train episode 51: -1768.982833245663
# Total reward train episode 52: -2330.298522415656
# Total reward train episode 53: -2164.816616577238
# Total reward train episode 54: -2372.3114844831653
# Total reward train episode 55: -2938.0352758373383
# Total reward eval episode 55: -279.1558948679011
# Total reward train episode 56: -1743.283142296681
# Total reward train episode 57: -2693.589207951226
# Total reward train episode 58: -2036.569291209573
# Total reward train episode 59: -1986.8480673413117
# Total reward train episode 60: -2756.1240621651004
# Total reward eval episode 60: -185.8765160636603
# Total reward train episode 61: -2306.49934794526
# Total reward train episode 62: -3196.438269378836
# Total reward train episode 63: -891.2549005163366
# Total reward train episode 64: -2347.2600945239437
# Total reward train episode 65: -3359.6967787888575
# Total reward eval episode 65: -216.8999813747713
# Total reward train episode 66: -1811.3422755454828
# Total reward train episode 67: -2363.1041624792815
# Total reward train episode 68: -2542.0661195611187
# Total reward train episode 69: -2811.5395250467514
# Total reward train episode 70: -2504.817945024439
# Total reward eval episode 70: -255.98321049675317
# Total reward train episode 71: -2262.5730058702948
# Total reward train episode 72: -1497.4690410120902
# Total reward train episode 73: -2756.210709738502
# Total reward train episode 74: -1743.9198802428086
# Total reward train episode 75: -2775.5249890761606
# Total reward eval episode 75: -218.78784178356568
# Total reward train episode 76: -2067.8892597917143
# Total reward train episode 77: -2098.9913281246627
# Total reward train episode 78: -1701.0116818577583
# Total reward train episode 79: -2338.9465610962675
# Total reward train episode 80: -2118.148724887446
# Total reward eval episode 80: -263.30506076376605
# Total reward train episode 81: -2498.3474984024983
# Total reward train episode 82: -1827.3196382878477
# Total reward train episode 83: -1400.3172740280177
# Total reward train episode 84: -1509.765504646072
# Total reward train episode 85: -1722.8217199838643
# Total reward eval episode 85: -206.71523856760928
# Total reward train episode 86: -2099.394917142836
# Total reward train episode 87: -2043.72308953701
# Total reward train episode 88: -1807.700002266793
# Total reward train episode 89: -1847.6083623791023
# Total reward train episode 90: -1377.563808405323
# Total reward eval episode 90: -127.02325022581854
# Total reward train episode 91: -2438.4332661930443

# %% [markdown]
# ### Analyze the plots. Does SQL solve the multigoal environment?

# %% [markdown]
# ...

# %% [markdown]
# # Visualizing the value function
# As before, **visualze the learned value function of the SQL agent**. How does it relate to the reward landscape we saw earlier? How does it compare to the value function learned by NAF? How does it compare to the value function you drew on the paper?

# %%
# YOUR CODE HERE
# YOUR CODE HERE
import numpy as np
import matplotlib.pyplot as plt

size = 10
xlist = torch.from_numpy(np.linspace(-size, size, 100))
ylist = torch.from_numpy(np.linspace(-size, size, 100))

img = np.zeros((100,100))

for xi, x in enumerate(xlist):
  for yi, y in enumerate(ylist):
    #_, _, v, _ = sql_agent.q_net(torch.Tensor([x, y]).to(DEVICE))
    state = torch.Tensor([x, y]).to(DEVICE)
    states = []
    for i in range(100):
      states.append(state.tolist())
    states = torch.Tensor(states).to(DEVICE)
    proposal_actions = torch.tensor(
      np.random.uniform(
        -1,
        1,
        size=(100, 2)
      )
    ).to(torch.float32).to(DEVICE)
    q_soft = sql_agent.q_net.forward(torch.cat((states, proposal_actions), dim=1))

    v_soft = torch.logsumexp(q_soft, dim=0).unsqueeze(1)

    v_soft += torch.log(torch.tensor([2]).to(DEVICE)) * 2 #self.n_actions
    img[xi ,yi] = v_soft


plt.imshow(img)

# %% [markdown]
# # Visualizing the policy
# Now, lets also try to **visualize the policy network at interesting points in the environment**. These points coulde be $(0, 0), (\pm 2, 0),$ or $(\pm2.5, \pm2.5)$. Construct the observation manually, feed it into the policy network and visualize the particles. Bonus points if you run KDE on the generated particles ;)
# What do you observe? How does the plot of the particles and the KDE explain the shortcomming of the NAF algorithm on the multigoal environment?

# %%
# YOUR CODE HERE

# %% [markdown]
# ...

# %% [markdown]
# # Visualizing trajectories
# As we did before with NAF, lets explore trajectories taken by the learned SQL policy. **Collect, plot and analyze some (10 - 50) trajectories generated by the SQL agent**. Are the trajectories similar to what you drew on the paper?

# %%
# YOUR CODE HERE

# %% [markdown]
# ...

# %% [markdown]
# # Optional tasks:
# If you are done with everything and there is time left, we encourage you to do some (or all) of the following tasks:
# + Play with hyperparameters: For SQL, particularly interesting might be the reward scale, the number of particles used by the policy network with ASVGD, and the learning rates `Q_LR` and `PI_LR` (they might have an unespected relationship).
# + Generally, varying the batch size, the network size, the loss functions, and the optimizers target update rate `TAU` or hard update frequncy `HARD_FREQ` can have intersting effects. A poor value can often render the RL algorithm completely incapable of learning a task, while a good value can speed up and stabilize training considerably. Try varying those parameters and note the effects.
# + You can implement different explortation mechanisms. For example, the SQL implementation uses OU noise, which is a a form of temporally correlated noise and a rather powerful mechanism. How does SQL perform with, for example, epsilon greedy or Gaussian noise? In the same way, perhaps NAF can be improved by using OU noise instead of Gaussian or adaptive noise?
# + Lastly, given the somewhat complex ASVGD update mechanism in the SQL policy update, you can implement a simpler method like Metropolis Hastings or Hamiltonian Monte Carlo to sample from the policy.
